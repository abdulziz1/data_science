# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sps
import statsmodels as st
# %matplotlib inline

# %%
tips = pd.read_csv('seaborn-data-master/tips.csv')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sps.distplot(tips['total_bill'],kde=False,bins=40)

# %%
sps.jointplot(x='total_bill',y='tip',data=tips)

# %%
sps.pairplot(tips,hue='sex',palette='coolwarm')

# %%
sps.rugplot(tips['total_bill'])

# %%
sps.distplot(tips['total_bill'],kde=False)

# %%
"_______________________________________________________________________________________________________________________"
# Out:
# '_______________________________________________________________________________________________________________________'

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sps
import statsmodels as st
# %matplotlib inline
tips = pd.read_csv('seaborn-data-master/tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# sps.barplot(x='total_bill',y='sex',data=tips,estimator=mean)

# %%
sps.barplot(x='total_bill',y='sex',data=tips,estimator=np.mean)

# %%
sps.countplot(x='sex',data=tips)

# %%
sps.boxplot(x='total_bill',y='day',data=tips,hue='smoker')

# %%
sps.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)

# %%
sps.stripplot(x='day',y='total_bill',data=tips,jitter=False)

# %%
sps.swarmplot(x='day',y='total_bill',data=tips,color='red')
sps.violinplot(x='day',y='total_bill',data=tips,color='black')
sps.barplot(x='day',y='total_bill',data=tips,color='green')

# %%
sps.factorplot(x='day',y='total_bill',data=tips,kind='swarm')
# Out:
# C:\Program Files (x86)\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sps
import statsmodels as st
# %matplotlib inline
tips = pd.read_csv('seaborn-data-master/tips.csv')
flights=pd.read_csv('seaborn-data-master/flights.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tn = tips.corr()
tn.head()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sps.heatmap(tn,annot=True,robust=True,cmap='coolwarm')

# %%
tb = flights.pivot(index='month',columns='year',values='passengers')

# %%
sps.heatmap(tb,cmap='coolwarm',linecolor='black',linewidth=1)

# %%
sps.clustermap(tb,cmap='coolwarm',linewidth=1)

# %%
"______________________________________________________________________________________________________________________________"
# Out:
# '______________________________________________________________________________________________________________________________'

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sps
import statsmodels as st
# %matplotlib inline
tips = pd.read_csv('seaborn-data-master/tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sps.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],scatter_kws={'s':50})

# %%
sps.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',aspect=0.6,size=6)
# Out:
# C:\Program Files (x86)\anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-92c395a6e0e8> in <module>()
# ----> 1 time.head()
#
# NameError: name 'time' is not defined

# %%
"_______________________________________________________________________---------------------__________________________________|"
# Out:
# '_______________________________________________________________________---------------------__________________________________|'

# %%
pwd
# Out:
# 'C:\\Users\\الشاملة'

# %%
import seaborn as sps
import pandas as pd
# %matplotlib inline
iris = pd.read_csv('seaborn-data-master/iris.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
g = sps.PairGrid(iris)
g.map_diag(sps.distplot)
g.map_upper(sps.scatterplot)
g.map_lower(sps.kdeplot)

# %%
tips = pd.read_csv('seaborn-data-master/tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sps.FacetGrid(data=tips,col='smoker',row='time')
g.map(sps.scatterplot , 'total_bill' , 'tip')

# %%
"_____________________________________________________________________________________________________________________________"
# Out:
# '_____________________________________________________________________________________________________________________________'

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sps
import statsmodels as st
# %matplotlib inline
tips = pd.read_csv('seaborn-data-master/tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sps.set_context('notebook')
sps.countplot(x='sex',data=tips)

# %%
sps.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='plasma')

# %%
"______________________________________________________________________________________________________________________________"
# Out:
# '______________________________________________________________________________________________________________________________'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
import pandas as pd
titanic = pd.read_csv('seaborn-data-master/titanic.csv')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.jointplot(x='fare',y='age',data=titanic)

# %%
sns.boxplot(x='class',y='age',data=titanic,hue='age')

# %%
sns.swarmplot(x='class',y='age',data=titanic)

# %%
sns.countplot(x='sex',data=titanic)

# %%
bn = titanic.corr()
bn.head()
# Out:
#           survived    pclass       age     sibsp     parch      fare  \
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
#
#           adult_male     alone
# survived   -0.557080 -0.203367
# pclass      0.094035  0.135207
# age         0.280328  0.198270
# sibsp      -0.253586 -0.584471
# parch      -0.349943 -0.583398

# %%
sns.heatmap(bn,robust=True,cmap='coolwarm')

# %%
sns.distplot(titanic['fare'],kde=False,bins=30)

# %%
g = sns.FacetGrid(titanic,row='sex')
g.map(sns.distplot,'age')
